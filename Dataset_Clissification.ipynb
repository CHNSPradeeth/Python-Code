# %%
import pandas as pd

# Define the updated intents dictionary with 15 more intents
intentions = {
    "greetings": {
        "patterns": ["hi", "hello", "hey"],
        "responses": ["Hello sir, how are you?", "Welcome back, sir", "Good day, sir"]
    },
    "application": {
        "patterns": ["open", "can you open", "start"],
        "responses": ["Sure sir", "Working on it sir", "On it sir", "Certainly initiating"]
    },
    "how": {
        "patterns": ["how are you doing", "how are you jarvis", "are you there"],
        "responses": ["Great! sir", "I'm doing well, thank you!", "Fantastic sir"]
    },
    "thank_you": {
        "patterns": ["thanks", "thank you", "I appreciate it"],
        "responses": ["You're welcome, sir", "My pleasure, sir", "Always here to help"]
    },
    "weather": {
        "patterns": ["what's the weather", "tell me the weather", "weather update"],
        "responses": ["Checking the weather, sir", "Here's the latest weather", "Updating the weather for you"]
    },
    "time": {
        "patterns": ["what's the time", "current time", "tell me the time"],
        "responses": ["The current time is", "It's exactly", "Right now, it is"]
    },
    "date": {
        "patterns": ["what's the date", "current date", "tell me today's date"],
        "responses": ["Today's date is", "It is", "The current date is"]
    },
    "joke": {
        "patterns": ["tell me a joke", "make me laugh", "say something funny"],
        "responses": ["Why don’t scientists trust atoms? Because they make up everything!", "I'm here to serve humor too!", "Knock knock, who's there? A bot with jokes!"]
    },
    "music": {
        "patterns": ["play some music", "start music", "can you play music"],
        "responses": ["Playing your favorite tracks, sir", "Music is coming up", "Starting the music for you"]
    },
    "news": {
        "patterns": ["tell me the news", "news update", "what's the latest news"],
        "responses": ["Fetching the latest news, sir", "Here's today's news update", "Bringing you the news"]
    },
    "weather_forecast": {
        "patterns": ["what's the weather tomorrow", "weather forecast", "forecast for tomorrow"],
        "responses": ["I'll check tomorrow's weather for you", "Here's the forecast", "Updating you with tomorrow's weather"]
    },
    "alarm": {
        "patterns": ["set an alarm", "can you set an alarm", "schedule an alarm"],
        "responses": ["Setting the alarm", "Your alarm is ready", "Alarm is set, sir"]
    },
    "reminder": {
        "patterns": ["set a reminder", "can you remind me", "reminder for"],
        "responses": ["Reminder set", "I've noted your reminder", "Your reminder is saved"]
    },
    "calculator": {
        "patterns": ["calculate", "can you calculate", "math operation"],
        "responses": ["Let's do the math", "Calculating now", "I've got the result"]
    },
    "quote": {
        "patterns": ["tell me a quote", "inspire me", "give me some inspiration"],
        "responses": ["Here’s an inspiring quote for you", "Inspiration coming up", "Here's a quote to motivate you"]
    },
    "date_night": {
        "patterns": ["set up a date", "book a reservation", "date night planning"],
        "responses": ["Planning your date night, sir", "Setting things up", "Reservation is being made"]
    },
    "map": {
        "patterns": ["show me a map", "find a location", "where is"],
        "responses": ["Loading the map", "Here’s the location", "Showing directions"]
    },
    "lights": {
        "patterns": ["turn on the lights", "lights on", "control the lights"],
        "responses": ["Turning on the lights", "Lights are on, sir", "Controlling the lights now"]
    }
}

# Create lists to store patterns and intents
utterances = []
intent_list = []

# Extract patterns and intents from the updated intents dictionary
for intent, data in intentions.items():
    for pattern in data['patterns']:
        utterances.append(pattern)
        intent_list.append(intent)

# Create a DataFrame to represent the dataset
intentions_df = pd.DataFrame({'Pattern': utterances, 'Intent': intent_list})

# Display the dataset
print(intentions_df)
# Out:
#                         Pattern            Intent
# 0                            hi         greetings
# 1                         hello         greetings
# 2                           hey         greetings
# 3                          open       application
# 4                  can you open       application
# 5                         start       application
# 6             how are you doing               how
# 7            how are you jarvis               how
# 8                 are you there               how
# 9                        thanks         thank_you
# 10                    thank you         thank_you
# 11              I appreciate it         thank_you
# 12           what's the weather           weather
# 13          tell me the weather           weather
# 14               weather update           weather
# 15              what's the time              time
# 16                 current time              time
# 17             tell me the time              time
# ...
